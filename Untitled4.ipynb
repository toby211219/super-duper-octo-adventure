# %% [markdown]
# 我想做一個計算機,能夠加減
# --------------------------------------------------------------------------------
# 好的，這是一個可以進行加法和減法的簡單計算機程式碼。
#
# 好的，這個程式碼可以執行加法和減法。
#
# 接下來，您可以考慮增加更多功能，例如：
#
# 乘法和除法: 添加新的函數來處理乘法和除法運算。
# 使用者輸入: 讓使用者輸入數字，而不是直接在程式碼中指定。
# 錯誤處理: 處理可能的錯誤，例如除以零的情況。
# 更複雜的運算: 增加平方、平方根等功能。

# %% [markdown]
# 讓使用者輸入數字，而不是直接在程式碼中指定。
# --------------------------------------------------------------------------------
# 好的，我將修改程式碼，讓使用者可以輸入數字進行加法和減法運算。
#
# 現在程式碼可以讓使用者輸入數字進行計算了。接下來，您可以考慮增加乘法、除法或其他更複雜的運算功能，或者加入錯誤處理機制，例如檢查使用者輸入是否為有效的數字。

# %% [markdown]
# 增加乘法、除法
# --------------------------------------------------------------------------------
# 好的，我會修改程式碼，增加乘法和除法的功能。
#
# 現在計算機已經具備加、減、乘、除的功能了。
#
# 接下來，您可以考慮增加以下功能：
#
# 錯誤處理: 處理除以零的情況，避免程式崩潰。
# 迴圈: 讓使用者可以進行多次計算，而不用每次都重新執行程式碼。
# 選擇運算: 讓使用者選擇要執行的運算（加、減、乘、除）。
# 清除螢幕: 在每次計算後清除先前的輸出，讓介面更整潔。

# %% [markdown]
# 讓使用者選擇加減乘除，而不是全部顯示。
# --------------------------------------------------------------------------------
# 好的，我會修改程式碼，讓使用者選擇要執行的運算。
#
# 現在計算機已經可以讓使用者選擇運算並執行了。
#
# 接下來，您可以考慮增加以下功能：
#
# 錯誤處理: 處理除以零的情況，避免程式崩潰。
# 迴圈: 讓使用者可以進行多次計算，而不用每次都重新執行程式碼。
# 清除螢幕: 在每次計算後清除先前的輸出，讓介面更整潔。

# %% [markdown]
# 處理除以零的情況，避免程式崩潰。
# --------------------------------------------------------------------------------
# 好的，我會修改程式碼，在除法運算中加入除以零的錯誤處理。
#
# 您好，程式碼已經修改以處理除數為零的情況。
#
# 然而，程式碼執行失敗是因為您在輸入第二個數字時沒有輸入任何內容。請再執行一次程式碼，並在提示時輸入有效的數字。
#
# 接下來，您可以考慮增加以下功能：
#
# 迴圈: 讓使用者可以進行多次計算，而不用每次都重新執行程式碼。
# 清除螢幕: 在每次計算後清除先前的輸出，讓介面更整潔。
# 輸入驗證: 檢查使用者輸入是否為有效的數字，避免程式因無效輸入而崩潰。

# %% [markdown]
# 在每次計算後清除先前的輸出，讓介面更整潔
# --------------------------------------------------------------------------------
# 好的，我會修改程式碼，在每次計算後清除先前的輸出。
#
# 計算機現在已經可以在每次計算後清除輸出了，讓介面更整潔。
#
# 我們已經完成了：
#
# 加減乘除運算
# 讓使用者輸入數字
# 讓使用者選擇運算
# 處理除以零的錯誤
# 在每次計算後清除輸出
# 讓使用者可以進行多次計算 (通過加入迴圈)
# 讓使用者可以結束程式 (通過加入選項 5)
# 您還有其他想增加的功能嗎？例如：
#
# 輸入驗證: 檢查使用者輸入是否為有效的數字，避免程式因無效輸入而崩潰。
# 更多運算: 增加平方、平方根等功能。
# 更複雜的介面: 使用圖形介面而不是文字介面。

# %%
import os

def add(x, y):
  """This function adds two numbers"""
  return x + y

def subtract(x, y):
  """This function subtracts two numbers"""
  return x - y

def multiply(x, y):
  """This function multiplies two numbers"""
  return x * y

def divide(x, y):
  """This function divides two numbers"""
  if y == 0:
    return "錯誤：除數不能為零"
  else:
    return x / y

while True:
    print("選擇運算:")
    print("1. 加法")
    print("2. 減法")
    print("3. 乘法")
    print("4. 除法")
    print("5. 結束程式")

    # Get input from user
    choice = input("請輸入您的選擇(1/2/3/4/5): ")

    # Check if choice is one of the five options
    if choice in ('1', '2', '3', '4', '5'):
        if choice == '5':
            break
        num1 = float(input("請輸入第一個數字: "))
        num2 = float(input("請輸入第二個數字: "))

        if choice == '1':
            print(f"{num1} + {num2} = {add(num1, num2)}")

        elif choice == '2':
            print(f"{num1} - {num2} = {subtract(num1, num2)}")

        elif choice == '3':
            print(f"{num1} * {num2} = {multiply(num1, num2)}")

        elif choice == '4':
            result = divide(num1, num2)
            if isinstance(result, str):
                print(result)
            else:
                print(f"{num1} / {num2} = {result}")
        input("按 Enter 鍵繼續...")
        os.system('clear') # Clear the output
    else:
        print("輸入無效，請重新輸入。")
# Out:
# 選擇運算:
# 1. 加法
# 2. 減法
# 3. 乘法
# 4. 除法
# 5. 結束程式
# 請輸入您的選擇(1/2/3/4/5): 5
